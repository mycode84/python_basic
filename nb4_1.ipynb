# %%
name = "smith" # 길이
print(len(name)) 

# 오프셋(인덱싱)
print(name[2]) # i

print(name[1:3]) # 잘린값을 반환, 원본이 잘리는 게 아니다.

for x in name:
    print(x)

print(name[4:3:-1]) # 거꾸로


# 연결 연산 (불변객체 자체가 합쳐지는 것이 아닌 둘을 합친 불변객체가 새롭게 생성되는 것)
a = "py"
b = "thon"
print(a + b)

# 반복 연산
print("ha" * 3)

# 멤버쉽 연산 
print("py" in "python")
print("java" not in "python")

s = "python"
print(s[0])
# s[0] = "C" # error (문자열은 불변이니까 따로 변경 불가능)
# Out:
# 5
# i
# mi
# s
# m
# i
# t
# h
# h
# python
# hahaha
# True
# True
# p

# %%
print('python')
print("python")

# 여러줄 문자열

text = '''
안녕하세요
파이썬입니다
'''
print(text)

text = """
안녕하세요
파이썬입니다
"""
print(text)

# 이스케이프 문자 (줄바꿈)
print("Hello\nPython")

# Raw 문자열 : 문자열 안의 이스케이프 문자(\n, \t, \\ 등)를 특별하게 해석하지 않고 그대로 표현
print(r"C:\Users\data")

# f-string : 문자열 안에 변수 표현식{변수} 사용 (문자열 포맷방식)
name = "Tom"
print(f"이름은 {name}이다")

age = 20

print("나이는 " + str(age) + "입니다") # 숫자 객체를 문자열로 맞춰줘야만 함
print(f"나이는 {age}입니다") # f스트링 자체가 모든 문장을 문자열로 인식함
# Out:
# python
# python
#
# 안녕하세요
# 파이썬입니다
#
#
# 안녕하세요
# 파이썬입니다
#
# Hello
# Python
# C:\Users\data
# 이름은 Tom이다
# 나이는 20입니다
# 나이는 20입니다

# %%
a = "123"
b = "10"

print(a + b) # 12310 문자로 인식하기 때문

result = int(a) + int(b)

print(result)
# Out:
# 12310
# 133

# %%
s = "python" # dir 함수 : 객체의 모든 속성을 반환
print(dir(s))
print(s.upper()) # upper 메서드 : 대문자 변환
# 대부분의 객체 메서드는 자기자신은 수정, 문자열은 불변이기 때문에 새롭게 생성해서 반환
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# PYTHON

# %%
text = "Python Programming"

print(text.upper())      # 모두 대문자
print(text.lower())      # 모두 소문자
print(text.capitalize()) # 첫 글자만 대문자
print(text.title())      # 각 단어 첫 글자 대문자
# Out:
# PYTHON PROGRAMMING
# python programming
# Python programming
# Python Programming

# %%
text = "   Python   " # 글자 사이의 공백은 공백으로 인식하지 않기 때문에 제거 X

print(text.strip())   # 양쪽 공백 제거
print(text.lstrip())  # 왼쪽 공백 제거
print(text.rstrip())  # 오른쪽 공백 제거
# Out:
# Python
# Python
#    Python

# %%
text = "Python Programming" 

print(text.find("Pro"))
print(text.find("Java"))  # -1을 반환하면 글자를 찾지 못했다는 것
print(text.startswith("Python"))  # 성이 "김" name.startswith("김")
print(text.endswith("ing"))  # 파일 중에 한글 파일만 f.endswith(" .hwp")
# Out:
# 7
# -1
# True
# True

# %%
text = "I like Java"

print(text.replace("Java", "Python"))  # 원본을 그대로 사용하는 것이 아닌 카피를 해서 반환하는 것
# Out:
# I like Python

# %%
data = "apple,banana,orange"

result = data.split(",")

print(result) # ['apple', 'banana', 'orange']
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits = ["apple", "banana", "orange"]

result = " and ".join(fruits)

print(result)
# Out:
# apple and banana and orange

# %%
print("123".isdigit())      # 문자열이 숫자로만 구성되어 있는가?
print("Python".isalpha())   # 문자열이 영문자(또는 한글 등 문자)로만 구성되어 있는가?
print("Python123#".isalnum()) # 문자열이 문자와 숫자로만 구성되어 있는가? (특수문자는 포함 X)
# Out:
# True
# True
# False

# %%
num = "100" # 요즘은 f스트링 쓰다보니 잘 안 쓰는 메서드가 됨

print(num.zfill(5))    # 전체 길이가 5가 되도록 왼쪽을 0으로 채움
print(num.center(10))  # 전체 길이가 10이 되도록 가운데 정렬
print(num.ljust(10))   # 전체 길이가 10이 되도록 왼쪽 정렬
print(num.rjust(10))   # 전체 길이가 10이 되도록 오른쪽 정렬
# Out:
# 00100
#    100
# 100
#        100

# %%
phone1 = "010"
phone2 = "1234"
phone3 = "5678"

phone = "-".join([phone1, phone2, phone3])

print(phone)
# Out:
# 010-1234-5678

# %%
email = "python@test.com"

user_id = email.split("@")[0] #  # @를 기준으로 분리한 후 첫 번째 요소(인덱스 0) 추출

print(user_id)
# Out:
# python

# %%
# 1) 문자 채우기, 정렬
name = "Python"

print(f"{name:*<15}")  # 왼쪽 정렬, 빈칸은 *로 채움
print(f"{name:*^15}")  # 가운데 정렬, 빈칸은 *로 채움
print(f"{name:*>15}")  # 오른쪽 정렬, 빈칸은 *로 채움
# 변수 사용 가능
w = 15
print(f"{name:*>{w}}")  # 오른쪽 정렬, 빈칸은 *로 채움
# Out:
# Python*********
# ****Python*****
# *********Python
# *********Python

# %%
name = input("이름") # 키보드로 입력한 문자열을 반환 (엔트키 전)
print(name)
# Out:
# 안녀엉

# %%
x = input("x입력")
y = input("y입력")
print(int(x)+int(y))
# Out:
# 30

# %%
name = "Park"
age = 30

# f-string 기본 사용
print(f"이름: {name}, 나이: {age}")  # 변수 값을 문자열 안에 직접 삽입

# 소수점 자리수 지정
pi = 3.141592
print(f"{pi:.2f}")  # 소수점 둘째 자리까지 출력 → 3.14

# 자리수(폭) 지정
num = 7
print(f"{num:5}")   # 전체 5칸 확보, 오른쪽 정렬 → '    7'
print(f"{num:05}")  # 빈칸을 0으로 채움 → 00007
# Out:
# 이름: Park, 나이: 30
# 3.14
#     7
# 00007

# %%
# 왼쪽 정렬 (<), 오른쪽 정렬 (>), 가운데 정렬 (^)
print(f"{'Python':<10}")  # 왼쪽 정렬
print(f"{'Python':>10}")  # 오른쪽 정렬
print(f"{'Python':^10}")  # 가운데 정렬
# Out:
# Python
#     Python
#   Python

# %%
# f 스트링

# 기본 사용
print("이름: {}, 나이: {}".format("Park", 30))  # {} 순서대로 값 들어감

# 인덱스 사용
print("이름: {0}, 나이: {1}".format("Park", 30))  # 번호로 위치 지정

# 이름 지정
print("이름: {name}, 나이: {age}".format(name="Park", age=30))  
# 변수 이름으로 직접 지정 가능
# Out:
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30

# %%
name = "Park"
age = 30

# f-string 기본 사용
print(f"이름: {name}, 나이: {age}")  # 변수 값을 문자열 안에 직접 삽입

# 소수점 자리수 지정
pi = 3.141592
print(f"{pi:.2f}")  # 소수점 둘째 자리까지 출력 → 3.14

# 자리수(폭) 지정
num = 7
print(f"{num:5}")   # 전체 5칸 확보, 오른쪽 정렬 → '    7'
print(f"{num:05}")  # 빈칸을 0으로 채움 → 00007
# Out:
# 이름: Park, 나이: 30
# 3.14
#     7
# 00007

# %%
name = "Python"

print(f"{name:*<15}")
print(f"{name:*^15}")
print(f"{name:*>15}")

w = 15

print(f"{name:*>{w}}")

num = 123

print(f"{num:08}")
print(f"{num:010}")

a = 150
b = -50

print(f"{a:+}")
print(f"{b:+}")

c = 100
d = -100

print(f"{c: }")
print(f"{d: }")
# Out:
# Python*********
# ****Python*****
# *********Python
# *********Python
# 00000123
# 0000000123
# +150
# -50
#  100
# -100

# %%
s1 = "Python"
s2 = "Pytho" 
s2 = s2 + "n"
print(s1 is s2) # True
print(s1 == s2) # True
# Out:
# False
# True
