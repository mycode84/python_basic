# %%
# 가장 작은 단위의 값과 값을 만들어내는 표현식, 그리고 반복문·조건문·대입문 같은 문들이 모여 
# 하나의 모듈(.py 파일)을 이루고, 여러 모듈이 모여 패키지(폴더)를 이루며, 
# 여러 패키지와 모듈이 함께 하나의 프로그램을 구성한다.

# %%
from my_math import add

print(add(2,4))
# Out:
# 6

# %%
from my_math import add as a # as를 통해 add라는 이름을 a로 바꿔서 사용 가능 

print(a(2,4))
# Out:
# 6

# %%
# greet 패키지 안에 ko.py, en.py이라는 모듈이 있다

import greet.ko
greet.ko.ko_greet("미치에다슌스케")
# Out:
# '안녕하세요, 미치에다슌스케!'

# %%
from greet import en
en.en_greet("Kamishiraishi Mone")
# Out:
# 'Hello, Kamishiraishi Mone!'
